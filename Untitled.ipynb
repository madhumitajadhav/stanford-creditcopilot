# %%
import docx

# Create a document
doc = docx.Document()

# Add a paragraph to the document
p = doc.add_paragraph()

# Add some formatting to the paragraph
p.paragraph_format.line_spacing = 1
p.paragraph_format.space_after = 0

# Add a run to the paragraph

run = p.add_run("python-docx")

# Add some formatting to the run
run.bold = True
run.italic = True
run.font.name = 'Arial'
run.font.size = docx.shared.Pt(16)

# Add more text to the same paragraph
run = p.add_run(" Tutorial")

# Format the run
run.bold = True
run.font.name = 'Arial'
run.font.size = docx.shared.Pt(16)

# Add another paragraph (left blank for an empty line)
doc.add_paragraph()

# Add another paragraph
p = doc.add_paragraph()

# Add a run and format it
run = p.add_run("This is my first python-docx tutorial!")
run.font.name = 'Arial'
run.font.size = docx.shared.Pt(12)

# Save the document
doc.save("docx-python Tutorial Demo.docx")

# %%
# !pip3 install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-docx) (5.1.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-docx) (4.10.0)
# Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 4.0 MB/s eta 0:00:00 0:00:01
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.0

# %%
import docx

def write_into_doc(filename, text):
    # Create a document
    doc = docx.Document()
    
    # Add a paragraph to the document
    p = doc.add_paragraph()
    
    # Add some formatting to the paragraph
    p.paragraph_format.line_spacing = 1
    p.paragraph_format.space_after = 0
     
    # Add a run and format it
    run = p.add_run(text)
    run.font.name = 'Arial'
    run.font.size = docx.shared.Pt(12)
    
    # Save the document
    doc.save(filename+'.docx')

# %%
write_into_doc("temp", "Hello I am Madhumita")

# %%
output_directory= "LLM_Response/"

if (Path(output_directory).is_dir()):
  rmtree(output_directory)
os.makedirs(output_directory, exist_ok=True)

# %%
from shutil import rmtree 
from pathlib import Path
import os

# %%
from docx import Document
document = Document('testDocmod.docx')
paragraphs = document.paragraphs

#Store content of second paragraph
text = paragraphs[1].text

#Clear content
paragraphs[1]._p.clear()

#Recreate second paragraph
paragraphs[1].add_run('Appended part ' + text)
document.save("testDocmod.docx")
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[17], line 2
#       1 from docx import Document
# ----> 2 document = Document('testDocmod.docx')
#       3 paragraphs = document.paragraphs
#       5 #Store content of second paragraph
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/docx/api.py:23, in Document(docx)
#      16 """Return a |Document| object loaded from `docx`, where `docx` can be either a path
#      17 to a ``.docx`` file (a string) or a file-like object.
#      18
#      19 If `docx` is missing or ``None``, the built-in default document "template" is
#      20 loaded.
#      21 """
#      22 docx = _default_docx_path() if docx is None else docx
# ---> 23 document_part = Package.open(docx).main_document_part
#      24 if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      25     tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/docx/opc/package.py:116, in OpcPackage.open(cls, pkg_file)
#     113 @classmethod
#     114 def open(cls, pkg_file):
#     115     """Return an |OpcPackage| instance loaded with the contents of `pkg_file`."""
# --> 116     pkg_reader = PackageReader.from_file(pkg_file)
#     117     package = cls()
#     118     Unmarshaller.unmarshal(pkg_reader, package, PartFactory)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/docx/opc/pkgreader.py:22, in PackageReader.from_file(pkg_file)
#      19 @staticmethod
#      20 def from_file(pkg_file):
#      21     """Return a |PackageReader| instance loaded with contents of `pkg_file`."""
# ---> 22     phys_reader = PhysPkgReader(pkg_file)
#      23     content_types = _ContentTypeMap.from_xml(phys_reader.content_types_xml)
#      24     pkg_srels = PackageReader._srels_for(phys_reader, PACKAGE_URI)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/docx/opc/phys_pkg.py:21, in PhysPkgReader.__new__(cls, pkg_file)
#      19         reader_cls = _ZipPkgReader
#      20     else:
# ---> 21         raise PackageNotFoundError("Package not found at '%s'" % pkg_file)
#      22 else:  # assume it's a stream and pass it to Zip reader to sort out
#      23     reader_cls = _ZipPkgReader
#
# PackageNotFoundError: Package not found at 'testDocmod.docx'

# %%
def write_into_doc(filename, text):
    
    # Create a document
    doc = docx.Document()
    
    # Add a paragraph to the document
    p = doc.add_paragraph()
    
    # Add some formatting to the paragraph
    p.paragraph_format.line_spacing = 1
    p.paragraph_format.space_after = 0
     
    # Add a run and format it
    run = p.add_run(text)
    run.font.name = 'Arial'
    run.font.size = docx.shared.Pt(12)
    
    # Save the document
    doc.save(filename+'.docx')

# %%
write_into_doc("hello", "ABC")

# %%
import docx

# %%
from pathlib import Path 
player = "hello"
path = Path(f'{player}.docx')
path.touch()  # default exists_ok=True
with path.open('a') as highscore:
   highscore.write(f'Username:{player}')

# %%
# Create a document
doc = docx.Document()

# Add a paragraph to the document
p = doc.add_paragraph()

# Add some formatting to the paragraph
p.paragraph_format.line_spacing = 1
p.paragraph_format.space_after = 0
 
# Add a run and format it
run = p.add_run(text)
run.font.name = 'Arial'
run.font.size = docx.shared.Pt(12)

# Save the document
doc.save(filename+'.docx')

# %%
filename =  "hello.docx"
filepath = "LLM_Response/"

def add_text(filename, text):
    if (Path(filepath+filename)).is_file():
        doc = docx.Document(filepath+filename)
        fullText = []
        for para in doc.paragraphs:
            fullText.append(para.text)
        txt = '\n'.join(fullText)
        
        p = doc.add_paragraph()
        run = p.add_run(text)
        run.font.name = 'Arial'
        run.font.size = docx.shared.Pt(12)
        
        # Save the document
        doc.save(filepath+filename)
        
    else:
        doc = docx.Document()
        # Add a paragraph to the document
        p = doc.add_paragraph()
        
        # Add some formatting to the paragraph
        p.paragraph_format.line_spacing = 1
        p.paragraph_format.space_after = 0
         
        # Add a run and format it
        run = p.add_run(text)
        run.font.name = 'Arial'
        run.font.size = docx.shared.Pt(12)
        
        # Save the document
        doc.save(filepath+filename)

# %%
add_text("hello.docx", "I live in .")
# Out:
# in if --->

# %%
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
getText("LLM_Response/hello.docx")
# Out:
# 'I am Madhumita.\nI am Madhumita.\nI live in california.\nI live in India.\nI live in USA.'

# %%
output_directory= "LLM_Response/"

if (Path(output_directory).is_dir()):
  rmtree(output_directory)
os.makedirs(output_directory, exist_ok=True)

# %%
dir(doc)
# Out:
# ['_Document__body',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_block_width',
#  '_body',
#  '_element',
#  '_parent',
#  '_part',
#  'add_heading',
#  'add_page_break',
#  'add_paragraph',
#  'add_picture',
#  'add_section',
#  'add_table',
#  'core_properties',
#  'element',
#  'inline_shapes',
#  'iter_inner_content',
#  'paragraphs',
#  'part',
#  'save',
#  'sections',
#  'settings',
#  'styles',
#  'tables']

# %%
def write_into_doc(filename, text):
    if (Path(filename)).is_file():
        doc = docx.Document(filename)
        fullText = []
        for para in doc.paragraphs:
            fullText.append(para.text)
        txt = '\n'.join(fullText)
        
        p = doc.add_paragraph()
        run = p.add_run(text)
        run.font.name = 'Arial'
        run.font.size = docx.shared.Pt(12)
        
        # Save the document
        doc.save(filename)
        
    else:
        doc = docx.Document()
        # Add a paragraph to the document
        p = doc.add_paragraph()
        
        # Add some formatting to the paragraph
        p.paragraph_format.line_spacing = 1
        p.paragraph_format.space_after = 0
         
        # Add a run and format it
        run = p.add_run(text)
        run.font.name = 'Arial'
        run.font.size = docx.shared.Pt(12)
        
        # Save the document
        doc.save(filename)

# %%
filepath = "LLM_Response"
write_into_doc(filepath+"Discovery.docx", "Hellooooo")

# %%
from datetime import datetime
datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2024-03-28 15:42:23'
